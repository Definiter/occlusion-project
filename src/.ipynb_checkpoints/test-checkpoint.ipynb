# %%
# Test.
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import caffe
import sys
import time

imagenet_root = '/home/haow3/occlusion-project/data/imagenet/'
caffe_root = '/home/haow3/software/caffe-rc3/'
new_to_original_class_id = [99, 113, 132, 144, 321, 344, 386, 494, 497, 512, 525, 526, \
650, 656, 737, 763, 844, 848, 903, 945]
original_to_new_class_id = {512: 9, 321: 4, 386: 6, 99: 0, 132: 2, 848: 17, 497: 8,\
650: 12, 903: 18, 844: 16, 525: 10, 494: 7, 144: 3, 113: 1, 763: 15, 526: 11, 344: 5,\
656: 13, 737: 14, 945: 19}

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

caffe.set_device(1)
caffe.set_mode_gpu()

is_finetuned = True
net_name = 'all'
#net = caffe.Net(imagenet_root + 'model/bvlc_alexnet/deploy.prototxt',
#                imagenet_root + 'model/bvlc_alexnet/bvlc_alexnet.caffemodel',
#                caffe.TEST)
net = caffe.Net(imagenet_root + 'model/finetune_alexnet_{}/deploy.prototxt'.format(net_name),
                imagenet_root + 'model/finetune_alexnet_{}/finetune_alexnet_{}.caffemodel'.format(net_name, net_name),
                caffe.TEST)

# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
transformer.set_transpose('data', (2,0,1))
transformer.set_mean('data', np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy').mean(1).mean(1)) # mean pixel
transformer.set_raw_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB

# set net to batch size of 50
net.blobs['data'].reshape(50,3,227,227)

test_dataset = [(0.0, 0), (1.0/3, 3), (1.0/2, 3), (2.0/3, 2), (1.0, 1)]
positive_true = [0 for i in test_dataset]
image_sum = [0 for i in test_dataset]
accuracy = [0.0 for i in test_dataset]

start_time = time.time()
for index, (occlu_size, occlu_num) in enumerate(test_dataset):
    percent = str(int(100 * occlu_size * occlu_size))
    print percent, occlu_num
    test_file = open('{}dataset/test_{}_{}.txt'.format(imagenet_root, percent, str(occlu_num)), 'r')
    
    lines = test_file.readlines()
    image_sum[index] = len(lines)
    for i, line in enumerate(lines):
        # A possible optimization to consider: add occluders on the test image before feeding them.
        image_path, class_id = line.split(' ')
        class_id = int(class_id)
        net.blobs['data'].data[...] = transformer.preprocess('data', caffe.io.load_image(image_path))
        out = net.forward()
        predict_id = out['prob'][0].argmax()
        if is_finetuned:
            true_id = class_id
        else:
            true_id = new_to_original_class_id[class_id]
        now_time = time.strftime("%H:%M:%S", time.gmtime(int(time.time() - start_time)))
        if i % 100 == 0:
            print '[{}] {:5}/{:5}: {} {} {}'.format(now_time, i, image_sum[index], image_path, predict_id, true_id)
        if true_id == predict_id:
            positive_true[index] += 1        
    accuracy[index] = positive_true[index] / float(image_sum[index])
    
    print 'positive_true: ', positive_true
    print 'image_sum: ', image_sum
    print 'accuracy: ', accuracy
# Out:
# 0 0
# [00:00:00]     0/ 2000: /home/haow3/occlusion-project/data/imagenet/dataset/test_0_0/
/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03109150_27317_11_3_2_1.jpeg 9 9
# [00:06:01]  6200/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03109150_6167_11_3_2_2.jpeg 16 9
# [00:06:05]  6300/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_11747_11_3_0_0.jpeg 10 10
# [00:06:09]  6400/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_8397_11_3_0_1.jpeg 10 10
# [00:06:14]  6500/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_4782_11_3_0_2.jpeg 10 10
# [00:06:18]  6600/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_12610_11_3_1_0.jpeg 10 10
# [00:06:22]  6700/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_46387_11_3_1_1.jpeg 10 10
# [00:06:27]  6800/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_41214_11_3_1_2.jpeg 10 10
# [00:06:32]  6900/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_39364_11_3_2_0.jpeg 10 10
# [00:06:36]  7000/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_37705_11_3_2_1.jpeg 10 10
# [00:06:40]  7100/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03160309_12873_11_3_2_2.jpeg 10 10
# [00:06:45]  7200/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_22241_11_3_0_0.jpeg 13 11
# [00:06:51]  7300/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_7201_11_3_0_1.jpeg 11 11
# [00:06:55]  7400/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_8242_11_3_0_2.jpeg 11 11
# [00:07:01]  7500/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_4052_11_3_1_0.jpeg 18 11
# [00:07:05]  7600/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_3281_11_3_1_1.jpeg 11 11
# [00:07:10]  7700/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_8230_11_3_1_2.jpeg 11 11
# [00:07:16]  7800/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_4974_11_3_2_0.jpeg 11 11
# [00:07:20]  7900/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_3592_11_3_2_1.jpeg 11 11
# [00:07:26]  8000/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03179701_11766_11_3_2_2.jpeg 11 11
# [00:07:31]  8100/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_21940_11_3_0_0.jpeg 7 12
# [00:07:35]  8200/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_20995_11_3_0_1.jpeg 12 12
# [00:07:39]  8300/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_21263_11_3_0_2.jpeg 12 12
# [00:07:44]  8400/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_23364_11_3_1_0.jpeg 12 12
# [00:07:48]  8500/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_22069_11_3_1_1.jpeg 12 12
# [00:07:52]  8600/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_19215_11_3_1_2.jpeg 12 12
# [00:07:56]  8700/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_21541_11_3_2_0.jpeg 9 12
# [00:08:01]  8800/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_24001_11_3_2_1.jpeg 12 12
# [00:08:05]  8900/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03759954_21437_11_3_2_2.jpeg 12 12
# [00:08:09]  9000/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_10215_11_3_0_0.jpeg 13 13
# [00:08:13]  9100/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_9501_11_3_0_1.jpeg 13 13
# [00:08:18]  9200/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_10052_11_3_0_2.jpeg 13 13
# [00:08:22]  9300/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_5276_11_3_1_0.jpeg 13 13
# [00:08:26]  9400/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_5202_11_3_1_1.jpeg 13 13
# [00:08:30]  9500/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_16162_11_3_1_2.jpeg 13 13
# [00:08:35]  9600/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_6456_11_3_2_0.jpeg 13 13
# [00:08:42]  9700/18000: /home/haow3/occlusion-project/data/imagenet/dataset/test_11_3/n03770679_765_11_3_2_1.jpeg 13 13

# %%
print 'positive_true =', positive_true
print 'image_sum =' , image_sum
print 'accuracy =', accuracy
# Out:
# positive_true = [1848, 16314, 15815, 6686, 755]
# image_sum = [2000, 18000, 18000, 8000, 2000]
# accuracy = [0.924, 0.9063333333333333, 0.8786111111111111, 0.83575, 0.3775]
